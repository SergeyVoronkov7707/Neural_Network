# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, Input
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D 

from tensorflow.keras.layers import Dense, Flatten, Concatenate

from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.datasets import cifar10

import matplotlib.pyplot as plt
import os

# %%
# установка параметров нейросети
batch_size = 32
num_classes = 10
epochs = 5
data_augmentation = False
num_predictions = 20


(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'тренировочные примеры')
print(x_test.shape[0], 'тестовые примеры')

# преобразование матрицы чисел 0-9 в бинарную матрицу чисел 0-1
#трансформация лейблов в one-hot encoding
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 тренировочные примеры
# 10000 тестовые примеры

# %%
classes=['самолет', 'автомобиль', 'птица', 'кот', 'олень', 'собака', 'лягушка', 'лошадь', 'корабль', 'грузовик']

# %%
N = 110

plt.imshow(x_train[N][:,:,:])
plt.title('это : '+classes[np.argmax(y_train[N,:])])
plt.show()

# %%
# изменение размерности массива в 4D массив
x_train = x_train.reshape(x_train.shape[0], 32,32,3)
x_test = x_test.reshape(x_test.shape[0], 32,32,3)

# %% [markdown]
# # AlexNet

# %%
from tensorflow.keras.models import Model 
# инициализация  модели
input1= keras.layers.Input(shape=(32,32,3))
# первый сверточный слой
x1 = keras.layers.Conv2D(120, kernel_size=(5, 5), strides=(1, 1), activation='tanh',  padding="same")(input1)
print(f'размер x1 : {x1.shape}')
# второй пуллинговый слой
x2 = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding='same')(x1)
print(f'размер x2 : {x2.shape}')
# третий сверточный слой
x3 = keras.layers.Conv2D(120, kernel_size=(2, 2), strides=(1, 1), activation='tanh', padding='same')(x2)
print(f'размер x3: {x3.shape}')
# четвертый пуллинговый слой
x4 = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same')(x3)
print(f'размер x4: {x4.shape}')
# пятый  слой
x5 = keras.layers.Conv2D(120, kernel_size=(5, 5), strides=(1, 1), activation='tanh', padding='same')(x4)
print(f'размер x5: {x5.shape}')
x6 = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(x5)
print(f'размер x6: {x6.shape}')
# пятый  слой
x7 = keras.layers.Conv2D(120, kernel_size=(5, 5), strides=(1, 1), activation='tanh', padding='valid')(x6)
print(f'размер x7: {x7.shape}')
# сглаживание CNN выхода чтобы можно было его присоединить к полносвязногому слою
x8 = keras.layers.Flatten()(x7)
print(f'размер x8: {x8.shape}')
# шестой полносвязный слой
x9 = keras.layers.Dense(256, activation='tanh')(x8)

# выходной слой с функцией активации softmax
out_x = keras.layers.Dense(10, activation='softmax')(x9)


# Соберем полную модель сети от входа к выходу 
model1 = Model(inputs = input1, outputs = out_x) 
# сделаем несколько промежуточных выходов (через них посмотрим , что происходит в сети) 
model3 = Model(inputs = input1, outputs = x3)
model5 = Model(inputs = input1, outputs = x5)
# компилияция модели
model1.compile(loss=keras.losses.categorical_crossentropy, optimizer= 'Adam', metrics=["accuracy"])

# Обучаем модель
hist = model1.fit(x=x_train,y=y_train, epochs=100, batch_size=128, validation_data=(x_test, y_test), verbose=1)

test_score = model1.evaluate(x_test, y_test)
print("Test loss {:.2f}, accuracy {:.2f}%".format(test_score[0], test_score[1] * 100))
# Out:
# размер x1 : (None, 32, 32, 120)
# размер x2 : (None, 32, 32, 120)
# размер x3: (None, 32, 32, 120)
# размер x4: (None, 16, 16, 120)
# размер x5: (None, 16, 16, 120)
# размер x6: (None, 8, 8, 120)
# размер x7: (None, 4, 4, 120)
# размер x8: (None, 1920)
# Epoch 1/100
# 391/391 [==============================] - 52s 101ms/step - loss: 1.9229 - accuracy: 0.2957 - val_loss: 1.5831 - val_accuracy: 0.4176
# Epoch 2/100
# 391/391 [==============================] - 38s 97ms/step - loss: 1.4166 - accuracy: 0.4874 - val_loss: 1.3326 - val_accuracy: 0.5208
# Epoch 3/100
# 391/391 [==============================] - 38s 98ms/step - loss: 1.1709 - accuracy: 0.5842 - val_loss: 1.1485 - val_accuracy: 0.5892
# Epoch 4/100
# 391/391 [==============================] - 38s 97ms/step - loss: 1.0240 - accuracy: 0.6389 - val_loss: 1.0412 - val_accuracy: 0.6297
# Epoch 5/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.9071 - accuracy: 0.6804 - val_loss: 0.9532 - val_accuracy: 0.6638
# Epoch 6/100
# 391/391 [==============================] - 38s 98ms/step - loss: 0.8160 - accuracy: 0.7128 - val_loss: 0.9622 - val_accuracy: 0.6616
# Epoch 7/100
# 391/391 [==============================] - 38s 98ms/step - loss: 0.7340 - accuracy: 0.7450 - val_loss: 0.8845 - val_accuracy: 0.6951
# Epoch 8/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.6778 - accuracy: 0.7611 - val_loss: 0.8894 - val_accuracy: 0.6986
# Epoch 9/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.6036 - accuracy: 0.7906 - val_loss: 0.9052 - val_accuracy: 0.6985
# Epoch 10/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.5469 - accuracy: 0.8109 - val_loss: 0.8836 - val_accuracy: 0.6994
# Epoch 11/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.4998 - accuracy: 0.8275 - val_loss: 0.9022 - val_accuracy: 0.6999
# Epoch 12/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.4500 - accuracy: 0.8442 - val_loss: 0.8973 - val_accuracy: 0.7081
# Epoch 13/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.4075 - accuracy: 0.8586 - val_loss: 0.9001 - val_accuracy: 0.7057
# Epoch 14/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.3767 - accuracy: 0.8687 - val_loss: 0.9272 - val_accuracy: 0.7098
# Epoch 15/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.3315 - accuracy: 0.8858 - val_loss: 0.9534 - val_accuracy: 0.7078
# Epoch 16/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.3198 - accuracy: 0.8881 - val_loss: 0.9937 - val_accuracy: 0.7006
# Epoch 17/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.2975 - accuracy: 0.8962 - val_loss: 1.0040 - val_accuracy: 0.7037
# Epoch 18/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2793 - accuracy: 0.9031 - val_loss: 1.0154 - val_accuracy: 0.6972
# Epoch 19/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2769 - accuracy: 0.9032 - val_loss: 1.0858 - val_accuracy: 0.6872
# Epoch 20/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2662 - accuracy: 0.9073 - val_loss: 1.0849 - val_accuracy: 0.6962
# Epoch 21/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2521 - accuracy: 0.9124 - val_loss: 1.0709 - val_accuracy: 0.6916
# Epoch 22/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2284 - accuracy: 0.9206 - val_loss: 1.0854 - val_accuracy: 0.7103
# Epoch 23/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2292 - accuracy: 0.9202 - val_loss: 1.1146 - val_accuracy: 0.6981
# Epoch 24/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2498 - accuracy: 0.9119 - val_loss: 1.1217 - val_accuracy: 0.6917
# Epoch 25/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2570 - accuracy: 0.9086 - val_loss: 1.0958 - val_accuracy: 0.6968
# Epoch 26/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2510 - accuracy: 0.9101 - val_loss: 1.1450 - val_accuracy: 0.6926
# Epoch 27/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2510 - accuracy: 0.9113 - val_loss: 1.1263 - val_accuracy: 0.7001
# Epoch 28/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2377 - accuracy: 0.9159 - val_loss: 1.1460 - val_accuracy: 0.6978
# Epoch 29/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2378 - accuracy: 0.9156 - val_loss: 1.2081 - val_accuracy: 0.6921
# Epoch 30/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2237 - accuracy: 0.9201 - val_loss: 1.1760 - val_accuracy: 0.7000
# Epoch 31/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2255 - accuracy: 0.9199 - val_loss: 1.1593 - val_accuracy: 0.7005
# Epoch 32/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2187 - accuracy: 0.9228 - val_loss: 1.1839 - val_accuracy: 0.6974
# Epoch 33/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2481 - accuracy: 0.9098 - val_loss: 1.1994 - val_accuracy: 0.6885
# Epoch 34/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2558 - accuracy: 0.9083 - val_loss: 1.1675 - val_accuracy: 0.7015
# Epoch 35/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2509 - accuracy: 0.9112 - val_loss: 1.1960 - val_accuracy: 0.6911
# Epoch 36/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2454 - accuracy: 0.9120 - val_loss: 1.2136 - val_accuracy: 0.6967
# Epoch 37/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2254 - accuracy: 0.9195 - val_loss: 1.1866 - val_accuracy: 0.7033
# Epoch 38/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2131 - accuracy: 0.9243 - val_loss: 1.2067 - val_accuracy: 0.6955
# Epoch 39/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.2325 - accuracy: 0.9173 - val_loss: 1.1951 - val_accuracy: 0.6998
# Epoch 40/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2558 - accuracy: 0.9093 - val_loss: 1.4110 - val_accuracy: 0.6635
# Epoch 41/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2683 - accuracy: 0.9024 - val_loss: 1.2029 - val_accuracy: 0.6971
# Epoch 42/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2617 - accuracy: 0.9060 - val_loss: 1.1739 - val_accuracy: 0.6966
# Epoch 43/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2330 - accuracy: 0.9164 - val_loss: 1.1940 - val_accuracy: 0.6946
# Epoch 44/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2212 - accuracy: 0.9209 - val_loss: 1.2182 - val_accuracy: 0.6980
# Epoch 45/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2542 - accuracy: 0.9085 - val_loss: 1.2087 - val_accuracy: 0.6923
# Epoch 46/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.2613 - accuracy: 0.9060 - val_loss: 1.2041 - val_accuracy: 0.6969
# Epoch 47/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2630 - accuracy: 0.9064 - val_loss: 1.2271 - val_accuracy: 0.6908
# Epoch 48/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2517 - accuracy: 0.9084 - val_loss: 1.2592 - val_accuracy: 0.6865
# Epoch 49/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2470 - accuracy: 0.9120 - val_loss: 1.2571 - val_accuracy: 0.6877
# Epoch 50/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2709 - accuracy: 0.9027 - val_loss: 1.1780 - val_accuracy: 0.6976
# Epoch 51/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2704 - accuracy: 0.9026 - val_loss: 1.2635 - val_accuracy: 0.6839
# Epoch 52/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2622 - accuracy: 0.9062 - val_loss: 1.1891 - val_accuracy: 0.6968
# Epoch 53/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2338 - accuracy: 0.9170 - val_loss: 1.2217 - val_accuracy: 0.7025
# Epoch 54/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2509 - accuracy: 0.9111 - val_loss: 1.2581 - val_accuracy: 0.6857
# Epoch 55/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2819 - accuracy: 0.8994 - val_loss: 1.2090 - val_accuracy: 0.6851
# Epoch 56/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.2477 - accuracy: 0.9108 - val_loss: 1.2165 - val_accuracy: 0.6929
# Epoch 57/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2512 - accuracy: 0.9109 - val_loss: 1.2443 - val_accuracy: 0.6842
# Epoch 58/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.2643 - accuracy: 0.9040 - val_loss: 1.2610 - val_accuracy: 0.6910
# Epoch 59/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2615 - accuracy: 0.9067 - val_loss: 1.2141 - val_accuracy: 0.6933
# Epoch 60/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2742 - accuracy: 0.9029 - val_loss: 1.2042 - val_accuracy: 0.6940
# Epoch 61/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2551 - accuracy: 0.9084 - val_loss: 1.2545 - val_accuracy: 0.6860
# Epoch 62/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2619 - accuracy: 0.9052 - val_loss: 1.2619 - val_accuracy: 0.6925
# Epoch 63/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2818 - accuracy: 0.8997 - val_loss: 1.3375 - val_accuracy: 0.6769
# Epoch 64/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2801 - accuracy: 0.8990 - val_loss: 1.2288 - val_accuracy: 0.6895
# Epoch 65/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2708 - accuracy: 0.9025 - val_loss: 1.2423 - val_accuracy: 0.6865
# Epoch 66/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2742 - accuracy: 0.9015 - val_loss: 1.2113 - val_accuracy: 0.6963
# Epoch 67/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2850 - accuracy: 0.8969 - val_loss: 1.2359 - val_accuracy: 0.6868
# Epoch 68/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2901 - accuracy: 0.8964 - val_loss: 1.2261 - val_accuracy: 0.6844
# Epoch 69/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2716 - accuracy: 0.9006 - val_loss: 1.2889 - val_accuracy: 0.6794
# Epoch 70/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2576 - accuracy: 0.9075 - val_loss: 1.2420 - val_accuracy: 0.6928
# Epoch 71/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2511 - accuracy: 0.9091 - val_loss: 1.1990 - val_accuracy: 0.6956
# Epoch 72/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.2859 - accuracy: 0.8978 - val_loss: 1.2321 - val_accuracy: 0.6816
# Epoch 73/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2803 - accuracy: 0.9000 - val_loss: 1.2524 - val_accuracy: 0.6838
# Epoch 74/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.3080 - accuracy: 0.8889 - val_loss: 1.2427 - val_accuracy: 0.6844
# Epoch 75/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2822 - accuracy: 0.8990 - val_loss: 1.2800 - val_accuracy: 0.6849
# Epoch 76/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2642 - accuracy: 0.9059 - val_loss: 1.2915 - val_accuracy: 0.6830
# Epoch 77/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.3179 - accuracy: 0.8855 - val_loss: 1.2768 - val_accuracy: 0.6673
# Epoch 78/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.3156 - accuracy: 0.8882 - val_loss: 1.2070 - val_accuracy: 0.6849
# Epoch 79/100
# 391/391 [==============================] - 37s 95ms/step - loss: 0.2959 - accuracy: 0.8950 - val_loss: 1.1815 - val_accuracy: 0.6894
# Epoch 80/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2834 - accuracy: 0.8986 - val_loss: 1.1728 - val_accuracy: 0.6936
# Epoch 81/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2857 - accuracy: 0.8983 - val_loss: 1.2703 - val_accuracy: 0.6860
# Epoch 82/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.2619 - accuracy: 0.9062 - val_loss: 1.2502 - val_accuracy: 0.6855
# Epoch 83/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2863 - accuracy: 0.8972 - val_loss: 1.2495 - val_accuracy: 0.6910
# Epoch 84/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.3214 - accuracy: 0.8850 - val_loss: 1.2175 - val_accuracy: 0.6919
# Epoch 85/100
# 391/391 [==============================] - 37s 96ms/step - loss: 0.3087 - accuracy: 0.8897 - val_loss: 1.1981 - val_accuracy: 0.6947
# Epoch 86/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2986 - accuracy: 0.8933 - val_loss: 1.2925 - val_accuracy: 0.6776
# Epoch 87/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.2925 - accuracy: 0.8940 - val_loss: 1.2500 - val_accuracy: 0.6824
# Epoch 88/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.3111 - accuracy: 0.8895 - val_loss: 1.1878 - val_accuracy: 0.6891
# Epoch 89/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.2831 - accuracy: 0.8977 - val_loss: 1.2137 - val_accuracy: 0.6833
# Epoch 90/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.2792 - accuracy: 0.8982 - val_loss: 1.2531 - val_accuracy: 0.6845
# Epoch 91/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.2862 - accuracy: 0.8977 - val_loss: 1.2103 - val_accuracy: 0.6853
# Epoch 92/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.2841 - accuracy: 0.8985 - val_loss: 1.2639 - val_accuracy: 0.6840
# Epoch 93/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.3164 - accuracy: 0.8892 - val_loss: 1.2455 - val_accuracy: 0.6898
# Epoch 94/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.3226 - accuracy: 0.8860 - val_loss: 1.3079 - val_accuracy: 0.6715
# Epoch 95/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.3422 - accuracy: 0.8780 - val_loss: 1.2262 - val_accuracy: 0.6758
# Epoch 96/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.3212 - accuracy: 0.8850 - val_loss: 1.2903 - val_accuracy: 0.6717
# Epoch 97/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.3081 - accuracy: 0.8894 - val_loss: 1.2663 - val_accuracy: 0.6792
# Epoch 98/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2808 - accuracy: 0.9001 - val_loss: 1.2169 - val_accuracy: 0.6842
# Epoch 99/100
# 391/391 [==============================] - 38s 97ms/step - loss: 0.3102 - accuracy: 0.8873 - val_loss: 1.2469 - val_accuracy: 0.6713
# Epoch 100/100
# 391/391 [==============================] - 38s 96ms/step - loss: 0.2935 - accuracy: 0.8943 - val_loss: 1.1896 - val_accuracy: 0.6962
# 313/313 [==============================] - 4s 13ms/step - loss: 1.1896 - accuracy: 0.6962
# Test loss 1.19, accuracy 69.62%

# %%
model1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 120)       9120
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 120)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 120)       57720
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 120)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 120)       360120
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 120)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 120)         360120
#
#  flatten (Flatten)           (None, 1920)              0
#
#  dense (Dense)               (None, 256)               491776
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 1,281,426
# Trainable params: 1,281,426
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model1,to_file='new_model-all.png')

# %%
y_pred = model1.predict(x_test)

# %%
# y_pred[10].max()
n = 110
print(classes[list(y_pred[n]).index(max(y_pred[n]))])
# Out:
# собака

# %%
N = 110

plt.imshow(x_test[N][:,:,:])
plt.title('это : '+classes[np.argmax(y_test[N,:])])
plt.show()

# %% [markdown]
# # Вывод по AlexNet
# после изменения п пулинговом слое с average на maxpooling и добавления еще двух слоев , кол-во итераций = 25, оптимайзер был изменен на Adam т.к. на прошлом уроке он показал лучший результат, точность на train выросла до 97% а на test до 65%
# уличение эпох до 100 и увелечение нейронов сильного прироста точности на тесте не дало, 69%, очень долго обучалась сеть, возможно если обучать еще дольше можно достигнуть нужного результата

# %%
from tensorflow.python.ops.gen_dataset_ops import multi_device_iterator_get_next_from_shard_eager_fallback
first_input = Input(shape=(32,32,3 ))
x11= Conv2D(128,3,activation='relu',padding = 'same')(first_input)
#x11= Flatten()(x11)
first_dense = x11# Dense(10, )(x11)

#second_input = Input(shape=(28,28,1 ))
x22= Conv2D(128,5,activation='relu',padding = 'same')(first_input)
#x22= Flatten()(x22)
second_dense = x22 #Dense(10, )(x22)

x111= Conv2D(128,3,activation='tanh',padding = 'same')(first_input)
#x11= Flatten()(x11)
first_dense2 = x111# Dense(10, )(x11)

#second_input = Input(shape=(28,28,1 ))
x222= Conv2D(128,5,activation='tanh',padding = 'same')(first_input)
#x22= Flatten()(x22)
second_dense2 = x222 #Dense(10, )(x22)

x1111= Conv2D(128,3,activation='tanh',padding = 'same')(first_input)
#x11= Flatten()(x11)
first_dense3 = x1111# Dense(10, )(x11)

#second_input = Input(shape=(28,28,1 ))
x2222= Conv2D(128,5,activation='tanh',padding = 'same')(first_input)
#x22= Flatten()(x22)
second_dense3 = x2222 #Dense(10, )(x22)

merge_one = Concatenate(   )([first_dense, second_dense])
merge_two = Concatenate(   )([first_dense2, second_dense2])
merge_three = Concatenate(   )([first_dense3, second_dense3])

third_input = Input(shape=(32,32,3 ))
x33= Conv2D(10,1,activation='relu',padding = 'same')(first_input)
#x33= Flatten()(x33)
#x33 = Dense(10, )(x33)
merge_four = Concatenate( axis=-1)([merge_one, merge_two])
merge_five = Concatenate( axis=-1)([ merge_three, x33])
merge_six = Concatenate( axis=-1)([ merge_four, merge_five])
x8 = keras.layers.Flatten()(merge_six)
print(f'размер x8: {x8.shape}')

merge_seven=Dense(10, activation='softmax')(x8)


model_stek = Model(inputs=first_input, outputs=merge_seven)
#model_stek = Model(inputs=[first_input, second_input, third_input], outputs=merge_two)
ada_grad = tf.keras.optimizers.Adagrad(lr=0.1, epsilon=1e-08, decay=0.0)
# model_stek.compile(optimizer=ada_grad, loss=tf.keras.losses.CategoricalCrossentropy(),
              # metrics=['accuracy'])
model_stek.compile(loss=keras.losses.categorical_crossentropy, optimizer= 'Adam', metrics=["accuracy"])


hist = model_stek.fit(x=x_train,y=y_train, epochs=100, batch_size=128, validation_data=(x_test, y_test), verbose=1)

test_score = model1.evaluate(x_test, y_test)
print("Test loss {:.2f}, accuracy {:.2f}%".format(test_score[0], test_score[1] * 100))
# Out:
# размер x8: (None, 796672)
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adagrad.py:74: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adagrad, self).__init__(name, **kwargs)
# Epoch 1/100
# 391/391 [==============================] - 72s 180ms/step - loss: 3.2169 - accuracy: 0.3929 - val_loss: 1.5197 - val_accuracy: 0.4860
# Epoch 2/100
# 391/391 [==============================] - 70s 179ms/step - loss: 1.3535 - accuracy: 0.5325 - val_loss: 1.3293 - val_accuracy: 0.5484
# Epoch 3/100
# 391/391 [==============================] - 70s 179ms/step - loss: 1.1474 - accuracy: 0.6006 - val_loss: 1.2790 - val_accuracy: 0.5588
# Epoch 4/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.9910 - accuracy: 0.6554 - val_loss: 1.2319 - val_accuracy: 0.5784
# Epoch 5/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.8673 - accuracy: 0.6976 - val_loss: 1.2547 - val_accuracy: 0.5847
# Epoch 6/100
# 391/391 [==============================] - 70s 180ms/step - loss: 0.7535 - accuracy: 0.7363 - val_loss: 1.2452 - val_accuracy: 0.5987
# Epoch 7/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.6783 - accuracy: 0.7646 - val_loss: 1.2768 - val_accuracy: 0.5998
# Epoch 8/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.5881 - accuracy: 0.7961 - val_loss: 1.3260 - val_accuracy: 0.5992
# Epoch 9/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.5166 - accuracy: 0.8228 - val_loss: 1.3854 - val_accuracy: 0.6015
# Epoch 10/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.4586 - accuracy: 0.8437 - val_loss: 1.5088 - val_accuracy: 0.5870
# Epoch 11/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.3920 - accuracy: 0.8676 - val_loss: 1.6176 - val_accuracy: 0.5832
# Epoch 12/100
# 391/391 [==============================] - 70s 179ms/step - loss: 23.7791 - accuracy: 0.5644 - val_loss: 4.1258 - val_accuracy: 0.4797
# Epoch 13/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.5841 - accuracy: 0.8195 - val_loss: 2.0772 - val_accuracy: 0.5672
# Epoch 14/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.3835 - accuracy: 0.8704 - val_loss: 1.9721 - val_accuracy: 0.5748
# Epoch 15/100
# 391/391 [==============================] - 72s 184ms/step - loss: 0.2930 - accuracy: 0.9055 - val_loss: 1.7868 - val_accuracy: 0.6037
# Epoch 16/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.2528 - accuracy: 0.9202 - val_loss: 1.7651 - val_accuracy: 0.6045
# Epoch 17/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.2145 - accuracy: 0.9375 - val_loss: 1.7562 - val_accuracy: 0.6023
# Epoch 18/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.1879 - accuracy: 0.9479 - val_loss: 1.7669 - val_accuracy: 0.6107
# Epoch 19/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.1783 - accuracy: 0.9514 - val_loss: 1.8063 - val_accuracy: 0.6042
# Epoch 20/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.1567 - accuracy: 0.9602 - val_loss: 1.8372 - val_accuracy: 0.6067
# Epoch 21/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.1400 - accuracy: 0.9672 - val_loss: 1.8785 - val_accuracy: 0.6011
# Epoch 22/100
# 391/391 [==============================] - 72s 183ms/step - loss: 0.1238 - accuracy: 0.9725 - val_loss: 1.8876 - val_accuracy: 0.6070
# Epoch 23/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.1102 - accuracy: 0.9763 - val_loss: 1.9930 - val_accuracy: 0.6022
# Epoch 24/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0996 - accuracy: 0.9797 - val_loss: 2.0771 - val_accuracy: 0.5961
# Epoch 25/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0900 - accuracy: 0.9822 - val_loss: 2.0802 - val_accuracy: 0.6019
# Epoch 26/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0895 - accuracy: 0.9816 - val_loss: 2.1869 - val_accuracy: 0.5938
# Epoch 27/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0951 - accuracy: 0.9780 - val_loss: 2.2060 - val_accuracy: 0.6002
# Epoch 28/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0651 - accuracy: 0.9891 - val_loss: 2.2908 - val_accuracy: 0.6020
# Epoch 29/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0598 - accuracy: 0.9884 - val_loss: 2.3587 - val_accuracy: 0.6007
# Epoch 30/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0712 - accuracy: 0.9829 - val_loss: 2.7551 - val_accuracy: 0.5737
# Epoch 31/100
# 391/391 [==============================] - 70s 178ms/step - loss: 19.7728 - accuracy: 0.7142 - val_loss: 3.2170 - val_accuracy: 0.5874
# Epoch 32/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.1583 - accuracy: 0.9470 - val_loss: 2.9207 - val_accuracy: 0.5948
# Epoch 33/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0771 - accuracy: 0.9786 - val_loss: 2.8098 - val_accuracy: 0.6080
# Epoch 34/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0508 - accuracy: 0.9877 - val_loss: 2.8289 - val_accuracy: 0.6054
# Epoch 35/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0343 - accuracy: 0.9943 - val_loss: 2.8842 - val_accuracy: 0.6034
# Epoch 36/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0289 - accuracy: 0.9958 - val_loss: 2.8456 - val_accuracy: 0.6045
# Epoch 37/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0251 - accuracy: 0.9970 - val_loss: 2.8440 - val_accuracy: 0.6053
# Epoch 38/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0378 - accuracy: 0.9918 - val_loss: 3.0090 - val_accuracy: 0.5912
# Epoch 39/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0281 - accuracy: 0.9959 - val_loss: 2.8831 - val_accuracy: 0.6053
# Epoch 40/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0303 - accuracy: 0.9946 - val_loss: 2.9026 - val_accuracy: 0.6079
# Epoch 41/100
# 391/391 [==============================] - 71s 183ms/step - loss: 0.0251 - accuracy: 0.9965 - val_loss: 2.9942 - val_accuracy: 0.6009
# Epoch 42/100
# 391/391 [==============================] - 72s 183ms/step - loss: 0.0264 - accuracy: 0.9960 - val_loss: 3.0478 - val_accuracy: 0.5922
# Epoch 43/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0497 - accuracy: 0.9882 - val_loss: 3.0433 - val_accuracy: 0.5988
# Epoch 44/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0384 - accuracy: 0.9919 - val_loss: 3.0578 - val_accuracy: 0.5974
# Epoch 45/100
# 391/391 [==============================] - 72s 183ms/step - loss: 0.0326 - accuracy: 0.9938 - val_loss: 3.0290 - val_accuracy: 0.6048
# Epoch 46/100
# 391/391 [==============================] - 72s 184ms/step - loss: 0.0276 - accuracy: 0.9951 - val_loss: 3.2058 - val_accuracy: 0.5901
# Epoch 47/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0275 - accuracy: 0.9951 - val_loss: 3.1765 - val_accuracy: 0.5970
# Epoch 48/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0175 - accuracy: 0.9978 - val_loss: 3.1847 - val_accuracy: 0.5972
# Epoch 49/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0163 - accuracy: 0.9982 - val_loss: 3.2367 - val_accuracy: 0.5994
# Epoch 50/100
# 391/391 [==============================] - 70s 179ms/step - loss: 25.3667 - accuracy: 0.8252 - val_loss: 10.3363 - val_accuracy: 0.4784
# Epoch 51/100
# 391/391 [==============================] - 70s 179ms/step - loss: 1.2216 - accuracy: 0.8247 - val_loss: 4.1400 - val_accuracy: 0.6098
# Epoch 52/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.1590 - accuracy: 0.9541 - val_loss: 4.6726 - val_accuracy: 0.5678
# Epoch 53/100
# 391/391 [==============================] - 70s 180ms/step - loss: 0.0774 - accuracy: 0.9792 - val_loss: 3.9760 - val_accuracy: 0.6013
# Epoch 54/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.2498 - accuracy: 0.9599 - val_loss: 4.1281 - val_accuracy: 0.5958
# Epoch 55/100
# 391/391 [==============================] - 72s 184ms/step - loss: 0.0159 - accuracy: 0.9965 - val_loss: 3.9518 - val_accuracy: 0.6086
# Epoch 56/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0118 - accuracy: 0.9978 - val_loss: 4.0415 - val_accuracy: 0.6056
# Epoch 57/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0127 - accuracy: 0.9977 - val_loss: 3.9958 - val_accuracy: 0.6056
# Epoch 58/100
# 391/391 [==============================] - 72s 183ms/step - loss: 0.0092 - accuracy: 0.9988 - val_loss: 3.9159 - val_accuracy: 0.6069
# Epoch 59/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0066 - accuracy: 0.9994 - val_loss: 3.9312 - val_accuracy: 0.6055
# Epoch 60/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0085 - accuracy: 0.9987 - val_loss: 3.9808 - val_accuracy: 0.6069
# Epoch 61/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0114 - accuracy: 0.9982 - val_loss: 4.0395 - val_accuracy: 0.6011
# Epoch 62/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0436 - accuracy: 0.9869 - val_loss: 4.1158 - val_accuracy: 0.5940
# Epoch 63/100
# 391/391 [==============================] - 72s 183ms/step - loss: 0.0530 - accuracy: 0.9844 - val_loss: 3.9794 - val_accuracy: 0.5985
# Epoch 64/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0247 - accuracy: 0.9938 - val_loss: 3.9302 - val_accuracy: 0.5997
# Epoch 65/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0145 - accuracy: 0.9971 - val_loss: 3.8914 - val_accuracy: 0.5991
# Epoch 66/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0104 - accuracy: 0.9984 - val_loss: 3.9701 - val_accuracy: 0.5997
# Epoch 67/100
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0162 - accuracy: 0.9966 - val_loss: 3.9494 - val_accuracy: 0.5987
# Epoch 68/100
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0129 - accuracy: 0.9975 - val_loss: 4.1349 - val_accuracy: 0.5911
# Epoch 69/100
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0538 - accuracy: 0.9836 - val_loss: 4.2266 - val_accuracy: 0.5866
# Epoch 70/100
# 391/391 [==============================] - 70s 178ms/step - loss: 26.4192 - accuracy: 0.7300 - val_loss: 5.2332 - val_accuracy: 0.6025
# Epoch 71/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.2234 - accuracy: 0.9473 - val_loss: 5.0716 - val_accuracy: 0.6001
# Epoch 72/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.1010 - accuracy: 0.9748 - val_loss: 4.9234 - val_accuracy: 0.6068
# Epoch 73/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0499 - accuracy: 0.9846 - val_loss: 4.9827 - val_accuracy: 0.6024
# Epoch 74/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0400 - accuracy: 0.9880 - val_loss: 4.8694 - val_accuracy: 0.6045
# Epoch 75/100
# 391/391 [==============================] - 72s 184ms/step - loss: 0.1169 - accuracy: 0.9777 - val_loss: 4.7301 - val_accuracy: 0.6106
# Epoch 76/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0139 - accuracy: 0.9963 - val_loss: 4.7836 - val_accuracy: 0.6090
# Epoch 77/100
# 391/391 [==============================] - 72s 183ms/step - loss: 0.0041 - accuracy: 0.9996 - val_loss: 4.8075 - val_accuracy: 0.6076
# Epoch 78/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0049 - accuracy: 0.9992 - val_loss: 4.7661 - val_accuracy: 0.6105
# Epoch 79/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0163 - accuracy: 0.9962 - val_loss: 4.8806 - val_accuracy: 0.6060
# Epoch 80/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.2115 - accuracy: 0.9678 - val_loss: 4.8092 - val_accuracy: 0.6053
# Epoch 81/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0092 - accuracy: 0.9982 - val_loss: 4.7151 - val_accuracy: 0.6085
# Epoch 82/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0036 - accuracy: 0.9998 - val_loss: 4.7410 - val_accuracy: 0.6087
# Epoch 83/100
# 391/391 [==============================] - 72s 185ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 4.7276 - val_accuracy: 0.6083
# Epoch 84/100
# 391/391 [==============================] - 70s 180ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 4.7433 - val_accuracy: 0.6084
# Epoch 85/100
# 391/391 [==============================] - 70s 180ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 4.7497 - val_accuracy: 0.6095
# Epoch 86/100
# 391/391 [==============================] - 70s 180ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 4.8589 - val_accuracy: 0.5971
# Epoch 87/100
# 391/391 [==============================] - 71s 181ms/step - loss: 0.1339 - accuracy: 0.9609 - val_loss: 4.9709 - val_accuracy: 0.5950
# Epoch 88/100
# 391/391 [==============================] - 70s 180ms/step - loss: 0.0404 - accuracy: 0.9874 - val_loss: 4.9416 - val_accuracy: 0.5972
# Epoch 89/100
# 391/391 [==============================] - 70s 180ms/step - loss: 0.0232 - accuracy: 0.9940 - val_loss: 4.8505 - val_accuracy: 0.5954
# Epoch 90/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0137 - accuracy: 0.9967 - val_loss: 4.8962 - val_accuracy: 0.5972
# Epoch 91/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0087 - accuracy: 0.9983 - val_loss: 4.8475 - val_accuracy: 0.5999
# Epoch 92/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0088 - accuracy: 0.9981 - val_loss: 5.0069 - val_accuracy: 0.5931
# Epoch 93/100
# 391/391 [==============================] - 70s 179ms/step - loss: 11.6705 - accuracy: 0.8124 - val_loss: 5.7448 - val_accuracy: 0.5987
# Epoch 94/100
# 391/391 [==============================] - 70s 180ms/step - loss: 0.0417 - accuracy: 0.9867 - val_loss: 5.6462 - val_accuracy: 0.5943
# Epoch 95/100
# 391/391 [==============================] - 72s 184ms/step - loss: 0.0229 - accuracy: 0.9926 - val_loss: 5.5437 - val_accuracy: 0.6011
# Epoch 96/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0084 - accuracy: 0.9980 - val_loss: 5.5968 - val_accuracy: 0.5958
# Epoch 97/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0164 - accuracy: 0.9956 - val_loss: 5.6452 - val_accuracy: 0.5980
# Epoch 98/100
# 391/391 [==============================] - 72s 183ms/step - loss: 0.0075 - accuracy: 0.9982 - val_loss: 5.5264 - val_accuracy: 0.6015
# Epoch 99/100
# 391/391 [==============================] - 70s 180ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 5.5045 - val_accuracy: 0.6003
# Epoch 100/100
# 391/391 [==============================] - 70s 179ms/step - loss: 0.0191 - accuracy: 0.9942 - val_loss: 5.5800 - val_accuracy: 0.5991
# 313/313 [==============================] - 4s 13ms/step - loss: 1.1896 - accuracy: 0.6962
# Test loss 1.19, accuracy 69.62%

# %%
plot_model(model_stek,'model_stek.png')

# %% [markdown]
# # Вывод по  Сетям со сложными конструкциями
# после добавления большего кол-ва слоев и увеличения нейронов до 50 сеть стала дольше обучаться, результат на тесте доходит до 60% а потом с очень маленьким шагом то выше, то ниже, но потихоньку через одну или две итерации всё таки вырастает
# После увелечения эпох до 100 и большего кол-ва нейронов результат вырос до 69%
